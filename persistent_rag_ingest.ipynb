# %%
from ingest import load_faq_data, build_index
documents = load_faq_data()

# %%
docs_llm = [doc for doc in documents if doc['course'] == 'llm-zoomcamp']
len(docs_llm)
# Out:
# 85

# %%
from sqlitesearch import TextSearchIndex

index = TextSearchIndex(
    text_fields=['question','section','answer'],
    keyword_fields=['course'],
    db_path='faq.db'
)

# %%
import time
for doc in docs_llm:
    index.add(doc)
    print(f'Added doc {doc["question"][:60]}...')
    time.sleep(0.5)  # Sleep for 100ms to avoid overwhelming the database
# Out:
# Added doc I just discovered the course. Can I still join?...
# Added doc Course: I have registered for the LLM Zoomcamp. When can I e...
# Added doc What is the video/zoom link to the stream for the “Office Ho...
# Added doc How should I start the course and follow the weekly workflow...
# Added doc Leaderboard: I am not on the leaderboard / how do I know whi...
# Added doc Certificate: Can I follow the course in a self-paced mode an...
# Added doc I missed the first homework - can I still get a certificate?...
# Added doc Homework: Why does the content keep changing?...
# Added doc When will the course be offered next?...
# Added doc Are there any lectures/videos? Where are they?...
# Added doc Where can I track the LLM Zoomcamp syllabus, deadlines, home...
# Added doc Are there live sessions or office hours for each module?...
# Added doc Can I use Bluesky for learning in public credits?...
# Added doc Where is the LLM Zoomcamp Telegram channel?...
# Added doc Why are we not using Langchain in the course?...
# Added doc OpenAI: Error when running OpenAI responses.create command...
# Added doc OpenAI: Error: RateLimitError: Error code: 429 -...
# Added doc OpenAI: How much will I have to spend to use the Open AI API...
# Added doc OpenAI: Do I have to subscribe and pay for Open AI API for t...
# Added doc Authentication: Why is my OPENAI_API_KEY not found in the Ju...
# Added doc How to store and load API keys using .env file...
# Added doc Can I use a model or provider different from the one recomme...
# Added doc How do I start using Google Gemini models in the Module 1 no...
# Added doc Ollama: How to install Ollama?...
# Added doc Connection refused error when prompting Ollama RAG...
# Added doc OpenAI: Why does my token count differ from what OpenAI repo...
# Added doc API keys: how do I set them once and not re-export every ter...
# Added doc How should I choose field weights for minsearch or another s...
# Added doc How should I prepare documents for RAG?...
# Added doc uv says Failed to hardlink files in Codespaces. Is it an err...
# Added doc dotenv is not recognized. What should I install?...
# Added doc Can I run the course locally instead of Codespaces?...
# Added doc What happens to code saved in Codespaces if I do not commit ...
# Added doc WSL2: ResponseError: model requires more system memory (X.X ...
# Added doc What are tools and functions in agentic RAG?...
# Added doc Any free models with tool use support?...
# Added doc Agents: "AttributeError: 'str' object has no attribute 'outp...
# Added doc I am using Azure OpenAI and I am still getting an error of E...
# Added doc Where can I find the homework questions?...
# Added doc Homework: Returning Empty list after filtering my query (HW ...
# Added doc OpenRouter: Error code 402 when calling responses.create (ma...
# Added doc What does it mean to point RAG at the chunk index in Module ...
# Added doc Do homework answers need to match the options exactly?...
# Added doc What should I do if homework questions feel unclear?...
# Added doc How do I get token counts for Module 1 homework if I use a d...
# Added doc What are embeddings?...
# Added doc Warning: 'model "multi-qa-mpnet-base-dot-v1" was made on sen...
# Added doc Why was .dot(...) used directly to compute cosine similarity...
# Added doc Vector search: should I embed the question, the answer, or b...
# Added doc What is the cosine similarity?...
# Added doc Why does cosine similarity reduce to a matrix multiplication...
# Added doc Do I need a new GitHub repo for Module 2, or just a new code...
# Added doc Evaluation: "JSONDecodeError: Expecting value" when generati...
# Added doc Evaluation: Jupyter kernel crashes when embedding the ground...
# Added doc Evaluation: hitting rate limits while generating the ground-...
# Added doc In Windows OS: OSError: [WinError 126] The specified module ...
# Added doc OperationalError when running python prep.py: psycopg2. Oper...
# Added doc How set Pandas to show entire text content in a column. Usef...
# Added doc How to normalize vectors in a Pandas DataFrame column (or Pa...
# Added doc How to compute the quantile or percentile of Pandas DataFram...
# Added doc How can I remove all Docker containers, images, and volumes,...
# Added doc Session State: I want the user to only be able to give feedb...
# Added doc Docker: When trying to run a streamlit app using docker-comp...
# Added doc Is it a group project?...
# Added doc Do we submit 2 projects, what does attempt 1 and 2 mean?...
# Added doc Does the competition count as the capstone?...
# Added doc How is my capstone project going to be evaluated?...
# Added doc When and how will we be assigned projects for review/grading...
# Added doc I’ve already submitted my project. Why can’t I review any pr...
# Added doc How can I find some good ideas or datasets for the project?...
# Added doc Project: do I need an orchestration tool (Airflow, Mage, Kes...
# Added doc Project: how do I evaluate a recommender-style RAG (no obvio...
# Added doc Project: my corpus is large (long PDFs, many paragraphs). Wh...
# Added doc Project: what does "reproducibility" mean — do reviewers nee...
# Added doc Can I use something other than Python for homework or the pr...
# Added doc Where can I find previous LLM Zoomcamp projects?...
# Added doc Do I need to announce or reserve my project idea?...
# Added doc Can I use the workshop materials for my own projects or shar...
# Added doc How to set up a new dlt project when loading from cloud?...
# Added doc There is an error when opening the table using `dbtable = db...
# Added doc There is an error when running main(): FileNotFoundError: Ta...
# Added doc How do I know which tables are in the db?...
# Added doc Does DLT have connectors to ClickHouse or StarRocks?...
# Added doc Notebook does not have secret access or 401 Client Error: Un...
# Added doc Error: How to fix requests library only installs v2.28 inste...
